# %%
# import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # import necessary libraries
# ----> 2 import pandas as pd
#       3 import numpy as np
#       4 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df = pd.read_csv('/content/MOCK_DATA.csv')
df
# Out:
#        id first_name last_name                  email       gender  \
# 0       1    Hadrian    Bridie    hbridie0@cdbaby.com         Male
# 1       2       Doll     Gawne       dgawne1@phoca.cz       Female
# 2       3      Decca      Prop    dprop2@redcross.org          NaN
# 3       4       Babs     Lande       blande3@xing.com  Genderqueer
# 4       5    Barrett  O'Brogan    bobrogan4@wikia.com         Male
# ..    ...        ...       ...                    ...          ...
# 995   996     Maxine   Drayson  mdraysonrn@utexas.edu       Female
# 996   997     Hurlee     Joule      hjoulero@lulu.com         Male
# 997   998    Richart   Koschke   rkoschkerp@patch.com         Male
# 998   999     Giffie   Merring   gmerringrq@tmall.com         Male
# 999  1000     Giorgi  Winspare     gwinsparerr@gov.uk          NaN
#
#           ip_address    salary
# 0      112.160.37.12   93144.0
# 1      229.3.141.136   69531.0
# 2     104.75.204.218       NaN
# 3     238.182.87.171   94304.0
# ...

# %%
# rows and columns
df.shape
# Out:
# (1000, 7)

# %%
# check column names
df.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'ip_address',
#        'salary'],
#       dtype='object')

# %%
# check data types
df.dtypes
# Out:
# id              int64
# first_name     object
# last_name      object
# email          object
# gender         object
# ip_address     object
# salary        float64
# dtype: object

# %%
# summary
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   int64
#  1   first_name  1000 non-null   object
#  2   last_name   1000 non-null   object
#  3   email       1000 non-null   object
#  4   gender      900 non-null    object
#  5   ip_address  1000 non-null   object
#  6   salary      900 non-null    float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 54.8+ KB

# %%
# convert gender to category data type
df['gender'].astype('category')
# Out:
# 0             Male
# 1           Female
# 2              NaN
# 3      Genderqueer
# 4             Male
#           ...
# 995         Female
# 996           Male
# 997           Male
# 998           Male
# 999            NaN
# Name: gender, Length: 1000, dtype: category
# Categories (8, object): ['Agender', 'Bigender', 'Female', 'Genderfluid', 'Genderqueer', 'Male',
#                          'Non-binary', 'Polygender']

# %%
df['gender'].str.lower()
# Out:
# 0             male
# 1           female
# 2              NaN
# 3      genderqueer
# 4             male
#           ...
# 995         female
# 996           male
# 997           male
# 998           male
# 999            NaN
# Name: gender, Length: 1000, dtype: object

# %%
# average salary
df['salary'].mean()
# Out:
# 137154.9411111111

# %%
# genderwise count
df['gender'].value_counts()
# Out:
# Male           411
# Female         395
# Non-binary      20
# Genderqueer     17
# Agender         15
# Polygender      15
# Bigender        14
# Genderfluid     13
# Name: gender, dtype: int64

# %%
# pie plot on gender
df['gender'].value_counts().plot(kind='pie',autopct='%.f%%')
# Out:
# <Axes: ylabel='gender'>

# %%
# data.rename(columns={'Number_Trucks_Sold':'Truck-Sales'}, inplace=True)
df.rename(columns={'email':'email_address'}, inplace=True)

# %%
df
# Out:
#        id first_name last_name          email_address       gender  \
# 0       1    Hadrian    Bridie    hbridie0@cdbaby.com         Male
# 1       2       Doll     Gawne       dgawne1@phoca.cz       Female
# 2       3      Decca      Prop    dprop2@redcross.org          NaN
# 3       4       Babs     Lande       blande3@xing.com  Genderqueer
# 4       5    Barrett  O'Brogan    bobrogan4@wikia.com         Male
# ..    ...        ...       ...                    ...          ...
# 995   996     Maxine   Drayson  mdraysonrn@utexas.edu       Female
# 996   997     Hurlee     Joule      hjoulero@lulu.com         Male
# 997   998    Richart   Koschke   rkoschkerp@patch.com         Male
# 998   999     Giffie   Merring   gmerringrq@tmall.com         Male
# 999  1000     Giorgi  Winspare     gwinsparerr@gov.uk          NaN
#
#           ip_address    salary
# 0      112.160.37.12   93144.0
# 1      229.3.141.136   69531.0
# 2     104.75.204.218       NaN
# 3     238.182.87.171   94304.0
# ...

# %%
'112.160.37.12'.split('.')
# Out:
# ['112', '160', '37', '12']

# %%
df['ip_address'].apply(lambda ip:ip.split('.'))
# Out:
# 0        [112, 160, 37, 12]
# 1        [229, 3, 141, 136]
# 2       [104, 75, 204, 218]
# 3       [238, 182, 87, 171]
# 4        [104, 60, 27, 200]
#                ...
# 995    [154, 175, 183, 168]
# 996     [125, 113, 145, 75]
# 997    [104, 236, 121, 243]
# 998       [112, 53, 45, 36]
# 999     [122, 46, 136, 150]
# Name: ip_address, Length: 1000, dtype: object

# %%
list(map(lambda ip:ip.split('.'),df['ip_address']))
# Out:
# [['112', '160', '37', '12'],
#  ['229', '3', '141', '136'],
#  ['104', '75', '204', '218'],
#  ['238', '182', '87', '171'],
#  ['104', '60', '27', '200'],
#  ['62', '109', '223', '68'],
#  ['96', '66', '60', '22'],
#  ['73', '62', '1', '60'],
#  ['1', '160', '28', '129'],
#  ['199', '175', '247', '0'],
#  ['50', '172', '75', '191'],
#  ['17', '111', '59', '5'],
#  ['161', '234', '25', '39'],
#  ['111', '4', '98', '41'],
#  ['44', '149', '216', '113'],
#  ['173', '100', '66', '195'],
#  ['189', '182', '166', '59'],
#  ['186', '146', '230', '179'],
#  ['188', '54', '19', '41'],
#  ['82', '232', '112', '45'],
#  ['76', '91', '58', '31'],
#  ['255', '187', '144', '242'],
#  ['191', '98', '27', '224'],
#  ['67', '90', '194', '97'],
#  ['19', '86', '177', '123'],
#  ['32', '74', '8', '62'],
#  ['46', '142', '171', '174'],
#  ['18', '241', '30', '184'],
#  ['130', '198', '66', '161'],
#  ['156', '232', '88', '12'],
#  ['95', '92', '45', '122'],
#  ['244', '103', '102', '214'],
# ...
